# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/5. London Housing Data.csv")
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
# Checking an overview of the data available
df.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
# Converting data type of date column to date-time format
df.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
df.date = pd.to_datetime(df.date)
df.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
# Adding a new column "year" in the dataframe that only contains year
df['year'] = df.date.dt.year
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
# Adding another column that only contains the month
df['month'] = df.date.dt.month
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year  month
# 0               NaN  1995      1
# 1               NaN  1995      2
# ...

# %%
# Position the month column as the second one on the dataset
df.insert(1 , 'months' , df.date.dt.month)
df
# Out:
#             date  months            area  average_price       code  \
# 0     1995-01-01       1  city of london          91449  E09000001
# 1     1995-02-01       2  city of london          82203  E09000001
# 2     1995-03-01       3  city of london          79121  E09000001
# 3     1995-04-01       4  city of london          77101  E09000001
# 4     1995-05-01       5  city of london          84409  E09000001
# ...          ...     ...             ...            ...        ...
# 13544 2019-09-01       9         england         249942  E92000001
# 13545 2019-10-01      10         england         249376  E92000001
# 13546 2019-11-01      11         england         248515  E92000001
# 13547 2019-12-01      12         england         250410  E92000001
# 13548 2020-01-01       1         england         247355  E92000001
#
#        houses_sold  no_of_crimes  year  month
# 0             17.0           NaN  1995      1
# 1              7.0           NaN  1995      2
# ...

# %%
# Removing the 'year' and 'month' columns from the dataset
df.drop(['month', 'year'], axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-8b4aa88992c1> in <module>
#       1 # Removing the 'year' and 'month' columns from the dataset
# ----> 2 df.drop(['month', 'year'], axis=1, inplace = True)
#       3 df
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df
# Out:
#             date  months            area  average_price       code  \
# 0     1995-01-01       1  city of london          91449  E09000001
# 1     1995-02-01       2  city of london          82203  E09000001
# 2     1995-03-01       3  city of london          79121  E09000001
# 3     1995-04-01       4  city of london          77101  E09000001
# 4     1995-05-01       5  city of london          84409  E09000001
# ...          ...     ...             ...            ...        ...
# 13544 2019-09-01       9         england         249942  E92000001
# 13545 2019-10-01      10         england         249376  E92000001
# 13546 2019-11-01      11         england         248515  E92000001
# 13547 2019-12-01      12         england         250410  E92000001
# 13548 2020-01-01       1         england         247355  E92000001
#
#        houses_sold  no_of_crimes
# 0             17.0           NaN
# 1              7.0           NaN
# 2             14.0           NaN
# ...

# %%
# Finding the number of records where the number of crimes is zero
len(df[df.no_of_crimes == 0])
# Out:
# 104

# %%
# Minimum and maximum average_price per year in England
df['year'] = df.date.dt.year
df.head()
# Out:
#         date  months            area  average_price       code  houses_sold  \
# 0 1995-01-01       1  city of london          91449  E09000001         17.0
# 1 1995-02-01       2  city of london          82203  E09000001          7.0
# 2 1995-03-01       3  city of london          79121  E09000001         14.0
# 3 1995-04-01       4  city of london          77101  E09000001          7.0
# 4 1995-05-01       5  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
df[df.area == 'england']
# Out:
#             date  months     area  average_price       code  houses_sold  \
# 13248 1995-01-01       1  england          53203  E92000001      47639.0
# 13249 1995-02-01       2  england          53096  E92000001      47880.0
# 13250 1995-03-01       3  england          53201  E92000001      67025.0
# 13251 1995-04-01       4  england          53591  E92000001      56925.0
# 13252 1995-05-01       5  england          53678  E92000001      64192.0
# ...          ...     ...      ...            ...        ...          ...
# 13544 2019-09-01       9  england         249942  E92000001      64605.0
# 13545 2019-10-01      10  england         249376  E92000001      68677.0
# 13546 2019-11-01      11  england         248515  E92000001      67814.0
# 13547 2019-12-01      12  england         250410  E92000001          NaN
# 13548 2020-01-01       1  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# ...

# %%
df1 = df[df.area == 'england'] # New dataframe
df1
# Out:
#             date  months     area  average_price       code  houses_sold  \
# 13248 1995-01-01       1  england          53203  E92000001      47639.0
# 13249 1995-02-01       2  england          53096  E92000001      47880.0
# 13250 1995-03-01       3  england          53201  E92000001      67025.0
# 13251 1995-04-01       4  england          53591  E92000001      56925.0
# 13252 1995-05-01       5  england          53678  E92000001      64192.0
# ...          ...     ...      ...            ...        ...          ...
# 13544 2019-09-01       9  england         249942  E92000001      64605.0
# 13545 2019-10-01      10  england         249376  E92000001      68677.0
# 13546 2019-11-01      11  england         248515  E92000001      67814.0
# 13547 2019-12-01      12  england         250410  E92000001          NaN
# 13548 2020-01-01       1  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# ...

# %%
df1.groupby('year').average_price.max()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %%
df1.groupby('year').average_price.min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
# Finding the maximum and minimum number of crimes that have been recorded per area
df.groupby('area').no_of_crimes.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
df.groupby('area').no_of_crimes.min().sort_values(ascending = False)
# Out:
# area
# westminster               3504.0
# lambeth                   2381.0
# southwark                 2267.0
# newham                    2130.0
# camden                    2079.0
# croydon                   2031.0
# islington                 1871.0
# ealing                    1871.0
# hackney                   1870.0
# brent                     1850.0
# barnet                    1703.0
# lewisham                  1675.0
# tower hamlets             1646.0
# enfield                   1635.0
# wandsworth                1582.0
# waltham forest            1575.0
# haringey                  1536.0
# hounslow                  1529.0
# greenwich                 1513.0
# redbridge                 1487.0
# hillingdon                1445.0
# bromley                   1441.0
# kensington and chelsea    1347.0
# hammersmith and fulham    1323.0
# barking and dagenham      1217.0
# havering                  1130.0
# harrow                     937.0
# bexley                     860.0
# ...

# %%
# Total count of areas where average price is less than 100000
df[df.average_price < 100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
